# %%
from sympy import *
init_printing(use_latex='mathjax')
Re,Da,theta_r,rho,alpha,H,eta,L_x,lam,tau,k,x = symbols('Re Da theta_r rho alpha H eta L_x lambda tau k x', positive=True)
V0 = symbols('V0')

# %%
rho    = solve(Re - rho*H*sqrt(4*H*eta/(rho*H)/theta_r)*L_x/(4*H*eta),rho)[0]     # density from Reynolds number Re
V_p    = sqrt(4*H*eta/(rho*H)/theta_r)                                            # velocity scale - wave velocity
alpha  = solve(Da - L_x**2*alpha**2/(4*H*eta),alpha)[0]

# %%
V     = V0*exp(-lam*tau*V_p/L_x)*sin(pi*k*x/L_x)
tauxx = V0*exp(-lam*tau*V_p/L_x)*cos(pi*k*x/L_x)

# %%
eq1 =   rho*H*diff(V,tau)      + diff(tauxx,x) + alpha**2*V   # momentum balance
eq2 = theta_r*diff(tauxx,tau)  + tauxx + 4*H*eta*diff(V,x)    # viscous stress

# %%
disp = diff(eq1,tau)*theta_r - diff(eq2,x) + eq1
disp = expand(disp)
disp = expand(simplify(disp/disp.coeff(lam**2)))
disp
# Out:
#      Da⋅λ           2  2    2
# Da - ──── - Re⋅λ + π ⋅k  + λ
#       Re

# %%
sol    = solve(disp,lam)
disc   = discriminant(disp,lam)
Re_opt = solve(disc,Re)[2].subs(k,1)
Re_opt
# Out:
#    _________
#   ╱       2
# ╲╱  Da + π   + π

# %%
from sympy import maximum, lambdify
import numpy as np
import warnings
warnings.filterwarnings('ignore')
lam       = [re(s.subs(k,1)) for s in sol]
lamf      = lambdify([Re,Da],lam,"numpy")
Ref       = lambdify(Da,Re_opt,"numpy")
Re1       = np.linspace(np.pi/2,5*np.pi,500)
Da1       = np.linspace(0,100,600)
[Re2,Da2] = np.meshgrid(Re1,Da1)
lam2      = np.stack(lamf(Re2,Da2),axis=0)
lam2      = np.nanmin(lam2,axis=0)
Re_opt1   = Ref(Da1)
lam1      = np.stack(lamf(Re_opt1,Da1),axis=0)
lam1      = np.nanmin(lam1,axis=0)

# %%
# %matplotlib widget
from matplotlib import pyplot as plt
from matplotlib import cm
plt.rcParams.update({"text.usetex": True, "font.size": 14})
f   = plt.figure(figsize=(7,5))
ax  = plt.subplot()
pos = ax.contourf(Re2,Da2,lam2,10,cmap=cm.cool)
ax.contour(Re2,Da2,lam2,10,linewidths=1,colors='k')
ax.plot(Re_opt1,Da1,ls='--',linewidth=3,color='w')
ax.set_xlabel("$Re$"); ax.set_ylabel("$Da$")
ax.set_xticks([np.pi/2,2*np.pi,3*np.pi,4*np.pi,5*np.pi])
ax.set_xticklabels(["$\pi/2$","$2\pi$","$3\pi$","$4\pi$","$5\pi$"])
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
cbar = f.colorbar(pos,ax=ax)
cbar.set_label("$\mathrm{min}\{\Re(\lambda_k)\}$")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
